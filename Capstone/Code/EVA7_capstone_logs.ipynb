# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import json
import cv2
import torch
import torch
import requests
import PIL
from PIL import Image, ImageDraw, ImageFont
from PIL import Image
from PIL import Image
import requests
import io
import math
import matplotlib.pyplot as plt
import numpy as np

# %%
cd /content/drive/MyDrive/Colab Notebooks/EVA7 Capstone/Part 3/detr/
# Out:
# /content/drive/MyDrive/Colab Notebooks/EVA7 Capstone/Part 3/detr

# %% [markdown]
# # Logs for Segmentation

# %%
import util
from util.plot_utils import plot_logs

from pathlib import Path

log_directory = [Path('/content/drive/MyDrive/Colab Notebooks/EVA7 Capstone/Part 3/detr/segmentation_output')]

# %%
fields_of_interest = (
    'loss',
    'mAP',
    )

plot_logs(log_directory,
          fields_of_interest)

# %%
fields_of_interest = (
    'loss_ce',
    'loss_bbox',
    'loss_giou',
  
    
    )

plot_logs(log_directory,
          fields_of_interest)

# %%
fields_of_interest = (
    'class_error',
    'cardinality_error_unscaled',
    )

plot_logs(log_directory,
          fields_of_interest)

# %% [markdown]
# # Logs for BBOX

# %%
from util.plot_utils import plot_logs

from pathlib import Path

bbox_log_directory = [Path('/content/drive/MyDrive/Colab Notebooks/EVA7 Capstone/Part 3/detr/bbox_output')]

# %%
fields_of_interest = (
    'loss',
    'mAP',
    )

plot_logs(bbox_log_directory,
          fields_of_interest)

# %%
fields_of_interest = (
    'loss_ce',
    'loss_bbox',
    'loss_giou',
  
    
    )

plot_logs(bbox_log_directory,
          fields_of_interest)

# %%
fields_of_interest = (
    'class_error',
    'cardinality_error_unscaled',
    )

plot_logs(bbox_log_directory,
          fields_of_interest)
